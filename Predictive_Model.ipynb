# %%
import numpy as np
import pandas as pd

# %%
Master14 = pd.read_excel('~/Desktop/Gaurav IPL Project/Final Output/Combined/MasterSheet/2014MasterSheet.xlsx')
Master15 = pd.read_excel('~/Desktop/Gaurav IPL Project/Final Output/Combined/MasterSheet/2015MasterSheet.xlsx')

# %%
for index in range(0, len(Master14)):
    Master14['Role'][index] = Master14['Role'][index].lower()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Master14WithAuction = Master14
Master14['Salary(Rupees Crore)'] = None

# %%
for i in range(0, len(Master14)):
    presence = False
    for index in range(0, len(Master15)):
        if Master14['Player Name'][i] == Master15['Player Name'][index]:
            Master14['Salary(Rupees Crore)'][i] = Master15['Salary(Rupees Crore)'][index]
            presence = True
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
Master14.dropna(inplace = True)

# %%
Master14.reset_index(inplace = True)

# %%
pd.DataFrame(Master14.groupby('Role'))
# Out:
#                                                  0  \
# 0                                      all rounder
# 1                                      all-rounder
# 2                                          batsman
# 3                           batsman, wicket-keeper
# 4                            batsman, wicketkeeper
# 5                              batting all-rounder
# 6    batting all-rounder, occasional wicket-keeper
# 7                                           bowler
# 8                              bowler, all-rounder
# 9                              bowling all rounder
# 10                             bowling all-rounder
# 11                            middle-order batsman
# 12  middle-order batsman, occasional wicket-keeper
# 13                                          opener
# 14                                 opening batsman
# 15                  opening batsman, wicket keeper
# 16                  opening batsman, wicket-keeper
# ...

# %%
Allrounder14 = pd.DataFrame(columns = Master14.columns)
Allrounder14['Unnamed: 0'] = Master14['Unnamed: 0']

# %%
count = 0
for index in range(0, len(Master14)):
    a = Master14['Role'][index].find('all rounder')
    b = Master14['Role'][index].find('all-rounder')
    c = Master14['Role'][index].find('allrounder')
    if a != -1 or b != -1 or c != -1:
        print('Yes!')
        for i in Master14.columns:
            Allrounder14[i][count] = Master14[i][index]
        count = count + 1
    else:
        print('No')
# Out:
# No
# No
# No
# No
# No
# Yes!
# No
# Yes!
# Yes!
# No
# No
# No
# Yes!
# No
# Yes!
# No
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# Yes!
# Yes!
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# Yes!
# Yes!
# No
# No
# No
# No
# Yes!
# No
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# Yes!
# No
# Yes!
# No
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# Yes!
# Yes!
# Yes!
# No
# Yes!
# No
# No
# Yes!
# No
# No
# No
# Yes!
# Yes!
# No
# No
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# Yes!
# Yes!
# No
# No
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
Allrounder14.dropna(inplace=True)

# %%
Batting14 = pd.DataFrame(columns = Master14.columns)
Batting14['Unnamed: 0'] = Master14['Unnamed: 0']

# %%
count = 0
for index in range(0, len(Master14)):
    a = Master14['Role'][index].find('bat')
    b = Master14['Role'][index].find('all')
    c = Master14['Role'][index].find('wicket')
    d = Master14['Role'][index].find('occasional')
    e = Master14['Role'][index].find('opener')
    f = Master14['Role'][index].find('order')
    if (a != -1 and b == -1 and c == -1) or (c != -1 and d != -1 and a != -1 and b==-1) or e != -1 or f!=-1:
        print('Yes!')
        for i in Master14.columns:
            Batting14[i][count] = Master14[i][index]
        count = count + 1
    else:
        print('No')
# Out:
# No
# Yes!
# No
# No
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# Yes!
# No
# No
# No
# No
# Yes!
# Yes!
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# Yes!
# Yes!
# Yes!
# Yes!
# No
# Yes!
# Yes!
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# Yes!
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# Yes!
# Yes!
# No
# No
# Yes!
# No
# No
# Yes!
# Yes!
# No
# No
# No
# No
# Yes!
# Yes!
# No
# No
# No
# No
# No
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
Batting14.dropna(inplace=True)

# %%
Bowling14 = pd.DataFrame(columns = Master14.columns)
Bowling14['Unnamed: 0'] = Master14['Unnamed: 0']

# %%
count = 0
for index in range(0, len(Master14)):
    a = Master14['Role'][index].find('bowl')
    b = Master14['Role'][index].find('all')
    c = Master14['Role'][index].find('wicket')
    if (a != -1 and b == -1 and c == -1):
        print('Yes!')
        for i in Master14.columns:
            Bowling14[i][count] = Master14[i][index]
        count = count + 1
    else:
        print('No')
# Out:
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# Yes!
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# Yes!
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# Yes!
# Yes!
# Yes!
# Yes!
# Yes!
# No
# No
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# Yes!
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# Yes!
# No
# Yes!
# No
# Yes!
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# Yes!
# Yes!
# Yes!
# No
# No
# No
# No
# No
# No
# Yes!
# Yes!
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
Bowling14.dropna(inplace=True)

# %%
WKeeper14 = pd.DataFrame(columns = Master14.columns)
WKeeper14['Unnamed: 0'] = Master14['Unnamed: 0']

# %%
count = 0
for index in range(0, len(Master14)):
    a = Master14['Role'][index].find('wicket')
    b = Master14['Role'][index].find('occasional')
    if a != -1 and b==-1:
        print('Yes!')
        for i in Master14.columns:
            WKeeper14[i][count] = Master14[i][index]
        count = count + 1
    else:
        print('No')
# Out:
# Yes!
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# Yes!
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes!
# No
# No
# No
# No
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
WKeeper14.dropna(inplace=True)

# %%
Batting14['Intl./Dom.'] = Batting14['Intl./Dom.'].replace({'Intl.':1, 'Domestic':0})

# %%
XBatting14 = Batting14[['Age','Intl./Dom.', 'Innings','Runs', 'Batting Avg', 'Batting Strike Rate', 'Total 50s', 'Total 100s', 'Batting Avg Death', 'Batting Strike Rate Death', 'Batting Avg PowerPlay', 'Batting Strike Rate PowerPlay', 'Batting Avg T20I', 'Batting Strike Rate T20I']]

# %%
Batting14.columns
# Out:
# Index(['index', 'Unnamed: 0', 'Season', 'Player Name', 'DOB', 'Age',
#        'Salary(Rupees Crore)', 'Role', 'Country', 'Intl./Dom.', 'Matches',
#        'Innings', 'Not Outs', 'Runs', 'Batting Avg', 'Batting Strike Rate',
#        'Highest Score', 'Total 4s', 'Total 6s', 'Total 50s', 'Total 100s',
#        'Bowling Innings', 'Overs', 'Runs Conceded', 'Wickets Taken',
#        'Bowling Average', 'Econ Rate', 'Bowling Strike Rate', '4w', '5w',
#        'DeathOver', 'Batting Avg Death', 'Batting Strike Rate Death',
#        'Bowling Average in Death Overs', 'Bowling SR in Death Overs',
#        'Bowling Econ. Rate in Death Overs', 'PowerPlay',
#        'Batting Avg PowerPlay', 'Batting Strike Rate PowerPlay',
#        'Bowling Average in Powerplay Overs', 'Bowling SR in Powerplay Overs',
#        'Bowling Econ. Rate in Powerplay Overs', 'T20International',
#        'Batting Avg T20I', 'Batting Strike Rate T20I', 'Bowling Average T20I',
# ...

# %%
XBatting14 = XBatting14.replace('-', 0)

# %%
Master14.fillna('-', inplace = True)

# %%
Master14 = Master14.replace('-', 0)

# %%
array = []
for index in range(0, len(Batting14)):
        array.append(Batting14['Salary(Rupees Crore)'][index])

# %%
XBatting14
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b6ee8c439acf> in <module>
# ----> 1 XBatting14
#
# NameError: name 'XBatting14' is not defined

# %%
#Master15 = Master15.replace('-', 0)

# %%
import sklearn
#sklearn.linear_model.LinearRegression.fit
# let's pull our handy linear fitter from our 'prediction' toolbox: sklearn!
from sklearn import linear_model
import numpy as np    # Great for lists (arrays) of numbers

# We're splitting up our data set into groups called 'train' and 'test'
from sklearn.model_selection import train_test_split

x = XBatting14.values
#x = x[:, np.newaxis]
y = array

# set up our model
multiple = linear_model.LinearRegression(fit_intercept = True, normalize = True)

# train the model 
multiple.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
print('Our multiple linear model had an R^2 of: %0.3f'%multiple.score(x, y))
# Out:
# Our multiple linear model had an R^2 of: 0.871

# %%
prediction = multiple.predict(x)

# %%
import matplotlib.pyplot as plt
plt.plot([-5,15],[-5,15]) #Drawing in the line of equality so we can compare
plt.title("Predicted vs. Real Prices")
plt.xlabel("Real price")
plt.ylabel("Predicted price")
plt.plot(y, prediction, '.')
plt.show()

# %%
Bowling14
# Out:
#     Unnamed: 0 Season       Player Name                  DOB Age  \
# 0            3   2014        Abu Nechim  1988-05-11 00:00:00  25
# 1           10   2014      Ankit Sharma           20/04/1991  22
# 2           11   2014           A Nehra           29/04/1979  34
# 3           12   2014          AB Dinda           25/03/1984  29
# 4           16   2014     BW Hilfenhaus           15/03/1983  30
# 5           17   2014      BE Hendricks  1990-08-06 00:00:00  23
# 6           26   2014          DW Steyn           27/06/1983  30
# 7           31   2014       DS Kulkarni  1988-10-12 00:00:00  25
# 8           39   2014   Harbhajan Singh  1980-03-07 00:00:00  33
# 9           40   2014          HV Patel           23/11/1990  23
# 10          41   2014       Imran Tahir           27/03/1979  34
# 11          42   2014     Iqbal Abdulla  1989-02-12 00:00:00  24
# 12          44   2014          I Sharma  1988-02-09 00:00:00  25
# ...
