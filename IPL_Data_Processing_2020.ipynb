# %%
import numpy as np
import pandas as pd

# %%
output2013 = pd.read_excel('Duplicate2013.xlsx', header = 0)
output2013
# Out:
#      Unnamed: 0       Player Name  Salary  Matches  Innings  Not Outs  Runs  \
# 0             0      Aaron  Finch     NaN      NaN      NaN       NaN   NaN
# 1             1   AB  de Villiers     NaN      NaN      NaN       NaN   NaN
# 2             2   Abhinav  Mukund     NaN      NaN      NaN       NaN   NaN
# 3             3   Abhishek  Nayar     NaN      NaN      NaN       NaN   NaN
# 4             4       Abu  Nechim     NaN      NaN      NaN       NaN   NaN
# ..          ...               ...     ...      ...      ...       ...   ...
# 155         155    Wayne  Parnell     NaN      NaN      NaN       NaN   NaN
# 156         156  Wriddhiman  Saha     NaN      NaN      NaN       NaN   NaN
# 157         157     Yusuf  Pathan     NaN      NaN      NaN       NaN   NaN
# 158         158     Yuvraj  Singh     NaN      NaN      NaN       NaN   NaN
# 159         159      Zaheer  Khan     NaN      NaN      NaN       NaN   NaN
#
# ...

# %%
batting13 = pd.read_excel('2013 Batting.xlsx', sheet_name = 'Highest Score in a game', header = 0)
batting13
# Out:
#     Unnamed: 0  POS            PLAYER  Mat  Inns  NO  Runs   HS    Avg   BF  \
# 0           21   22      Aaron  Finch   14    14   0   456   67  32.57  336
# 1           27   28   AB  de Villiers   14    14   4   360   64  36.00  219
# 2           99  100   Abhinav  Mukund    1     1   0    19   19  19.00   21
# 3           81   82   Abhishek  Nayar   11     9   3    66  25*  11.00   73
# 4            9   10   Adam  Gilchrist   13    13   1   294  85*  24.50  229
# ..         ...  ...               ...  ...   ...  ..   ...  ...    ...  ...
# 95           4    5      Virat  Kohli   16    16   2   634   99  45.28  457
# 96           5    6  Virender  Sehwag   13    13   1   295  95*  24.58  233
# 97          56   57  Wriddhiman  Saha    3     3   0    70   39  23.33   56
# 98          17   18     Yusuf  Pathan   16    16   5   332   72  30.18  240
# 99          61   62     Yuvraj  Singh   13    13   1   238   34  19.83  190
#
#         SR  100  50  4s  6s
# ...

# %%
bowling13 = pd.read_excel('2013 Bowling.xlsx', sheet_name = 'Most Wickets', header = 0)
bowling13
# Out:
#     Unnamed: 0  POS             PLAYER  Mat  Inns    Ov  Runs  Wkts  BBI  \
# 0            0    1      Dwayne  Bravo   18    18  62.3   497    32    0
# 1            1    2    James  Faulkner   16    16  63.1   427    28    0
# 2            2    3   Harbhajan  Singh   19    19  70.0   456    24    0
# 3            3    4  Mitchell  Johnson   17    17  64.0   459    24    0
# 4            4    5       Vinay  Kumar   16    16  60.1   493    23    0
# ..         ...  ...                ...  ...   ...   ...   ...   ...  ...
# 95          95   96      Yusuf  Pathan   16     5   9.0    73     1    0
# 96          96   97    Marlon  Samuels    2     1   4.0    34     1    0
# 97          97   98     Harmeet  Singh    1     1   4.0    34     1    0
# 98          98   99   Andrew  McDonald    1     1   2.0    17     1    0
# 99          99  100    Mohammad  Shami    3     3   9.0    78     1    0
#
#       Avg  Econ     SR  4w  5w
# 0   15.53  7.95  11.71   1   0
# ...

# %%
Bowlers13 = np.array(bowling13['PLAYER'])
Batsman13 = np.array(batting13['PLAYER'])

# %%
Players13 = pd.Series(np.concatenate((Batsman13, Bowlers13))).unique()

# %%
Players13 = np.sort(Players13)

# %%
df.to_excel('Duplicate2013.xlsx', sheet_name = 'Output1')

# %%
auction13 = pd.read_html('https://www.espncricinfo.com/story/_/id/21289074')
table = pd.DataFrame(auction13[0])
table.head(2)
# Out:
#      Player Name    Country                     IPL Team  Cost (USD)
# 0  Ricky Ponting  Australia               Mumbai Indians      400000
# 1       RP Singh      India  Royal Challengers Bangalore      400000

# %%
pd.merge(df, table, left_on='Player Name', right_on= 'Player Name')
# Out:
# Empty DataFrame
# Columns: [Player Name, Cost (USD)]
# Index: []

# %%
df.join(table.set_index('Player Name'),on = 'Player Name')
# Out:
#           Player Name  Cost (USD)
# 0     AB  de Villiers         NaN
# 1        Aaron  Finch         NaN
# 2     Abhinav  Mukund         NaN
# 3     Abhishek  Nayar         NaN
# 4         Abu  Nechim         NaN
# ..                ...         ...
# 155    Wayne  Parnell         NaN
# 156  Wriddhiman  Saha         NaN
# 157     Yusuf  Pathan         NaN
# 158     Yuvraj  Singh         NaN
# 159      Zaheer  Khan         NaN
#
# [160 rows x 2 columns]

# %%
batting13
# Out:
#     Unnamed: 0  POS            PLAYER  Mat  Inns  NO  Runs   HS    Avg   BF  \
# 0           21   22      Aaron  Finch   14    14   0   456   67  32.57  336
# 1           27   28   AB  de Villiers   14    14   4   360   64  36.00  219
# 2           99  100   Abhinav  Mukund    1     1   0    19   19  19.00   21
# 3           81   82   Abhishek  Nayar   11     9   3    66  25*  11.00   73
# 4            9   10   Adam  Gilchrist   13    13   1   294  85*  24.50  229
# ..         ...  ...               ...  ...   ...  ..   ...  ...    ...  ...
# 95           4    5      Virat  Kohli   16    16   2   634   99  45.28  457
# 96           5    6  Virender  Sehwag   13    13   1   295  95*  24.58  233
# 97          56   57  Wriddhiman  Saha    3     3   0    70   39  23.33   56
# 98          17   18     Yusuf  Pathan   16    16   5   332   72  30.18  240
# 99          61   62     Yuvraj  Singh   13    13   1   238   34  19.83  190
#
#         SR  100  50  4s  6s
# ...

# %%
batting13 = batting13[['PLAYER', 'Mat', 'Inns','NO', 'Runs','Avg', 'HS', 'SR', '4s', '6s', '50', '100']]

# %%
df.join(batting13).iloc[:3]
# Out:
#        Player Name           PLAYER   Mat  Inns   NO   Runs    Avg  HS  \
# 0  AB  de Villiers     Aaron  Finch  14.0  14.0  0.0  456.0  32.57  67
# 1     Aaron  Finch  AB  de Villiers  14.0  14.0  4.0  360.0  36.00  64
# 2  Abhinav  Mukund  Abhinav  Mukund   1.0   1.0  0.0   19.0  19.00  19
#
#        SR    4s    6s   50  100
# 0  135.71  54.0  16.0  4.0  0.0
# 1  164.38  34.0  15.0  2.0  0.0
# 2   90.47   1.0   0.0  0.0  0.0

# %%
batting13
# Out:
#               PLAYER  Mat  Inns  NO  Runs    Avg   HS      SR  4s  6s  50  100
# 0       Aaron  Finch   14    14   0   456  32.57   67  135.71  54  16   4    0
# 1    AB  de Villiers   14    14   4   360  36.00   64  164.38  34  15   2    0
# 2    Abhinav  Mukund    1     1   0    19  19.00   19   90.47   1   0   0    0
# 3    Abhishek  Nayar   11     9   3    66  11.00  25*   90.41   5   0   0    0
# 4    Adam  Gilchrist   13    13   1   294  24.50  85*  128.38  41   6   1    0
# ..               ...  ...   ...  ..   ...    ...  ...     ...  ..  ..  ..  ...
# 95      Virat  Kohli   16    16   2   634  45.28   99  138.73  64  22   6    0
# 96  Virender  Sehwag   13    13   1   295  24.58  95*  126.60  41   6   1    0
# 97  Wriddhiman  Saha    3     3   0    70  23.33   39  125.00   6   4   0    0
# 98     Yusuf  Pathan   16    16   5   332  30.18   72  138.33  30  14   1    0
# 99     Yuvraj  Singh   13    13   1   238  19.83   34  125.26  14  15   0    0
#
# [100 rows x 12 columns]

# %%
batting13['PLAYER'][0]
# Out:
# 'Aaron  Finch'

# %%
for i in range(0,160):
    for x in range(0,100):
        if df[0][i] == batting13['PLAYER'][x]:
            output2013['Matches'][i] = batting13['Mat'][x]
            output2013['Innings'][i] = batting13['Inns'][x]
            output2013['Not Outs'][i] = batting13['NO'][x]
            output2013['Runs'][i] = batting13['Runs'][x]
            output2013['Batting Avg'][i] = batting13['Avg'][x]
            output2013['Highest Score'][i] = batting13['HS'][x]
            output2013['Batting Strike Rate'][i] = batting13['SR'][x]
            output2013['Total 4s'][i] = batting13['4s'][x]
            output2013['Total 6s'][i] = batting13['6s'][x]
            output2013['Total 50s'][i] = batting13['50'][x]
            output2013['Total 100s'][i] = batting13['100'][x]
output2013
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
bowling13 = bowling13[['PLAYER', 'Mat', 'Inns','Ov', 'Runs', 'Wkts', 'Avg', 'Econ', 'SR', '4w', '5w']].sort_values(by = 'PLAYER', ascending = True)

# %%
for i in range(0,160):
    for x in range(0,100):
        if df[0][i] == bowling13['PLAYER'][x]:
            output2013['Matches'][i] = bowling13['Mat'][x]
            output2013['Innings'][i] = bowling13['Inns'][x]
            output2013['Overs'][i] = bowling13['Ov'][x]
            output2013['Runs Conceded'][i] = bowling13['Runs'][x]
            output2013['Bowling Average'][i] = bowling13['Avg'][x]
            output2013['Wickets Taken'][i] = bowling13['Wkts'][x]
            output2013['Econ Rate'][i] = bowling13['Econ'][x]
            output2013['Bowling Strike Rate'][i] = bowling13['SR'][x]
            output2013['4w'][i] = bowling13['4w'][x]
            output2013['5w'][i] = bowling13['5w'][x]
output2013
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
output2013.fillna('-', inplace=True)

# %%
output2013.to_excel('Final2013Output.xlsx', sheet_name= 'FOutput', index = False)

# %%
Players13 = pd.DataFrame(Players13)

# %%
Players13.iloc[0] = 'Aaron  Finch'
Players13.iloc[1] = 'AB  de Villiers'
Players13
# Out:
#                     0
# 0        Aaron  Finch
# 1     AB  de Villiers
# 2     Abhinav  Mukund
# 3     Abhishek  Nayar
# 4         Abu  Nechim
# ..                ...
# 155    Wayne  Parnell
# 156  Wriddhiman  Saha
# 157     Yusuf  Pathan
# 158     Yuvraj  Singh
# 159      Zaheer  Khan
#
# [160 rows x 1 columns]

# %%
def OutputYear(Year):
    batting = pd.read_excel(Year+' Batting.xlsx', sheet_name = 'Most Runs', header = 0)
    bowling = pd.read_excel(Year+' Bowling.xlsx', sheet_name = 'Most Wickets', header = 0)
    Batsman = np.array(batting['PLAYER'])
    Bowlers = np.array(bowling['PLAYER'])
    Players = pd.Series(np.concatenate((Batsman, Bowlers))).unique()
    df = pd.DataFrame(Players).sort_values(by = 0, ascending = True)
    df.to_excel(Year+'FinalOutput.xlsx', sheet_name = 'Output')
    output = df
    for count in range(1,len(output2013.columns)):
        output[output2013.columns[count]] = None
    output['Bowling Innings'] = None
    batting = batting[['PLAYER', 'Mat', 'Inns','NO', 'Runs','Avg', 'HS', 'SR', '4s', '6s', '50', '100']]
    for i in range(0,len(Players)):
        for x in range(0,len(Batsman)):
            if df[0][i] == batting['PLAYER'][x]:
                output['Matches'][i] = batting['Mat'][x]
                output['Innings'][i] = batting['Inns'][x]
                output['Not Outs'][i] = batting['NO'][x]
                output['Runs'][i] = batting['Runs'][x]
                output['Batting Avg'][i] = batting['Avg'][x]
                output['Highest Score'][i] = batting['HS'][x]
                output['Batting Strike Rate'][i] = batting['SR'][x]
                output['Total 4s'][i] = batting['4s'][x]
                output['Total 6s'][i] = batting['6s'][x]
                output['Total 50s'][i] = batting['50'][x]
                output['Total 100s'][i] = batting['100'][x]
    bowling = bowling[['PLAYER', 'Mat', 'Inns','Ov', 'Runs', 'Wkts', 'Avg', 'Econ', 'SR', '4w', '5w']]
    for i in range(0,len(Players)):
        for x in range(0,len(Bowlers)):
            if df[0][i] == bowling['PLAYER'][x]:
                output['Matches'][i] = bowling['Mat'][x]
                output['Bowling Innings'][i] = bowling['Inns'][x]
                output['Overs'][i] = bowling['Ov'][x]
                output['Runs Conceded'][i] = bowling['Runs'][x]
                output['Bowling Average'][i] = bowling['Avg'][x]
                output['Wickets Taken'][i] = bowling['Wkts'][x]
                output['Econ Rate'][i] = bowling['Econ'][x]
                output['Bowling Strike Rate'][i] = bowling['SR'][x]
                output['4w'][i] = bowling['4w'][x]
                output['5w'][i] = bowling['5w'][x]
    output.fillna('-', inplace=True)
    output.to_excel(Year+'FinalOutput.xlsx', sheet_name= 'FOutput', index = False)

# %%
for year in ['2013','2014','2015','2016','2017','2018','2019']:
    OutputYear(str(year))

# %%
salary19 = pd.read_html('https://www.iplt20.com/news/149387/vivo-ipl-2019-player-contract-extensions-announced', header = 1)
salary19_1 = salary19[0].iloc[:23]
salary19_1 = salary19_1[['Player', 'Salary']]
salary19_2 = salary19[0].iloc[:15]
salary19_2 = salary19_2[['Player.1', 'Salary.1']]
salary19_2.columns = ['Player', 'Salary']

# %%
salary19_3 = salary19[1].iloc[:10]
salary19_3 = salary19_3[['Player', 'Salary']]
salary19_4 = salary19[1].iloc[:13]
salary19_4 = salary19_4[['Player.1', 'Salary.1']]
salary19_4.columns = ['Player', 'Salary']

# %%
salary19_5 = salary19[2].iloc[:18]
salary19_5 = salary19_5[['Player', 'Salary']]
salary19_6 = salary19[2].iloc[:16]
salary19_6 = salary19_6[['Player.1', 'Salary.1']]
salary19_6.columns = ['Player', 'Salary']

# %%
salary19_7 = salary19[3].iloc[:15]
salary19_7 = salary19_7[['Player', 'Salary']]
salary19_8 = salary19[3].iloc[:20]
salary19_8 = salary19_8[['Player.1', 'Salary.1']]
salary19_8.columns = ['Player', 'Salary']

# %%
salary19 = pd.concat([salary19_1, salary19_2, salary19_3, salary19_4, salary19_5, salary19_6, salary19_7, salary19_8]).sort_values(by='Player')

# %%
data = pd.read_excel('2018FinalOutput.xlsx')
arr = []
for row in data['Player Name']:
    arr = np.append(arr, ' '.join(row.split()))

# %%
data['Player Name'] = arr

# %%
def tableclean_year(year):
    data = pd.read_excel(str(year)+'FinalOutput.xlsx')
    arr = []
    for row in data['Player Name']:
        arr = np.append(arr, ' '.join(row.split()))
    data['Player Name'] = arr
    
    data.to_excel(str(year)+'FinalOutput.xlsx', sheet_name='Final Table')

# %%
tableclean_year(2013)

# %%
for file in ['2014', '2015','2016','2017','2018', '2019']:
    tableclean_year(file)

# %%
data = pd.read_excel('2019FinalOutput.xlsx')
for i in range(0, len(data['Player Name'])):
    for x in range(0, len(salary19)):
        if data['Player Name'][i] == salary19['Player'][x]:
            data['Salary'][i] = salary19['Salary'][x]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
data.to_excel('2019FinalOutput.xlsx', sheet_name = 'Sheet1')

# %%
salary17 = pd.read_html('https://www.iplt20.com/news/38750/vivo-ipl-2017-player-retention-list', header = 1)

# %%
salary17_1 = salary17[1].iloc[:16]
salary17_1 = salary17_1[['Player Name', 'Bid Amount']]
salary17_2 = salary17[1].iloc[:16]
salary17_2 = salary17_2[['Player Name.1', 'Bid Amount.1']]
salary17_2.columns = ['Player Name', 'Bid Amount']

# %%
salary17_3 = salary17[1].iloc[24:43]
salary17_3 = salary17_3[['Player Name', 'Bid Amount']]
salary17_4 = salary17[1].iloc[24:38]
salary17_4 = salary17_4[['Player Name.1', 'Bid Amount.1']]
salary17_4.columns = ['Player Name', 'Bid Amount']

# %%
salary17_5 = salary17[1].iloc[51:71]
salary17_5 = salary17_5[['Player Name', 'Bid Amount']]
salary17_6 = salary17[1].iloc[51:69]
salary17_6 = salary17_6[['Player Name.1', 'Bid Amount.1']]
salary17_6.columns = ['Player Name', 'Bid Amount']

# %%
salary17_7 = salary17[1].iloc[79:99]
salary17_7 = salary17_7[['Player Name', 'Bid Amount']]
salary17_8 = salary17[1].iloc[79:96]
salary17_8 = salary17_8[['Player Name.1', 'Bid Amount.1']]
salary17_8.columns = ['Player Name', 'Bid Amount']

# %%
salary17 = pd.concat([salary17_1, salary17_2, salary17_3, salary17_4, salary17_5, salary17_6, salary17_7, salary17_8, auction17]).sort_values(by='Player Name')

# %%
salary17.set_index(np.arange(0,205), inplace = True)

# %%
salary17.head(4)
# Out:
#         Player Name Bid Amount
# 0    AB de Villiers   95000000
# 1       Aaron Finch   10000000
# 2  Abhimanyu Mithun    3000000
# 3        Adam Milne    7000000

# %%
data = pd.read_excel('2017FinalOutput.xlsx')
for i in range(0, len(data['Player Name'])):
    for x in range(0, len(salary17)):
        if data['Player Name'][i] == salary17['Player Name'][x]:
            data['Salary'][i] = salary17['Bid Amount'][x]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
data.to_excel('2017FinalOutput.xlsx', sheet_name = 'Final Output')

# %%
auction17 = pd.read_html('https://www.cricketcountry.com/news/ipl-2017-auction-complete-list-of-sold-players-with-price-indian-premier-league-10-578311')

# %%
auction17 = auction17[0].iloc[2:]

# %%
auction17.columns = ['Player Name', 'Bid Amount']

# %%
auction17.set_index(np.arange(0,65), inplace = True)

# %%
auction17
# Out:
#         Player Name Bid Amount
# 0       Eoin Morgan   20000000
# 1        Pawan Negi   10000000
# 2    Angelo Mathews   20000000
# 3        Ben Stokes  145000000
# 4    Corey Anderson   10000000
# ..              ...        ...
# 60   Aksh Deep Nath    1000000
# 61     Darren Bravo    5000000
# 62     Manoj Tiwary    5000000
# 63      Sayan Ghosh    1000000
# 64  Lockie Ferguson    5000000
#
# [65 rows x 2 columns]

# %%
import requests

url = 'https://starsunfolded.com/salary-of-ipl-players/'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

salary18 = pd.read_html(r.text)

# %%
salary18['Salary'].str.split().get(0)[:2]
# Out:
# ['₹11', 'crore']

# %%
salary18_1 = salary18[0]
salary18_2 = salary18[1]

# %%
salary18 = pd.concat([salary18[0], salary18[1], salary18[2], salary18[3], salary18[4], salary18[5], salary18[6], salary18[7]])

# %%
salary18.sort_values(by='Player Name', inplace = True)

# %%
salary18 = salary18.set_index(np.arange(0,189))

# %%
salary18
# Out:
#                   Player Name                Salary                   Role  \
# 0              AB de Villiers  ₹11 crore (Retained)                Batsman
# 1                 Aaron Finch            ₹6.2 crore                Batsman
# 2             Abhishek Sharma              ₹55 lakh            Spin-bowler
# 3                 Aditya Tare              ₹20 lakh  Wicket-keeper batsman
# 4    Ajinkya Rahane (Captain)              ₹4 crore                Batsman
# ..                        ...                   ...                    ...
# 184           Wriddhiman Saha              ₹5 crore  Wicket-keeper batsman
# 185              Yusuf Pathan            ₹1.9 crore            All-rounder
# 186              Yuvraj Singh              ₹2 crore                Batsman
# 187          Yuzvendra Chahal              ₹6 crore            Spin-bowler
# 188                Zahir Khan              ₹60 lakh            Spin-bowler
#
#           Country
# 0    South Africa
# 1       Australia
# ...

# %%
data = pd.read_excel('2018FinalOutput.xlsx')
for i in range(0, len(data['Player Name'])):
    for x in range(0, len(salary18)):
        if data['Player Name'].str.split().get(i)[:2] == salary18['Player Name'].str.split().get(x)[:2]:
            data['Salary'][i] = salary18['Salary'][x]
            data['Role'][i] = salary18['Role'][x]
            data['Country'][i] = salary18['Country'][x]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ...

# %%
data.to_excel('2018FinalOutput.xlsx')

# %%
salary15 = pd.read_html('https://www.iplt20.com/news/39087', header = 0)

# %%
salary15 = salary15[0][['Player', 'Country', 'Actual Salary (INR)']]

# %%
auction15_1 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-chennai-super-kings-csk-for-ipl-8-251184', header = 0)

# %%
auction15_1 = auction15_1[0]

# %%
auction15_2 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-delhi-daredevils-dd-for-ipl-8-251187', header = 0)

# %%
auction15_2 = auction15_2[0]

# %%
auction15_3 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-kings-xi-punjab-kxip-for-ipl-8-251200', header = 0)

# %%
auction15_3 = auction15_3[0]

# %%
auction15_4 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-kolkata-knight-riders-kkr-for-ipl-8-251167', header = 0)

# %%
auction15_4 = auction15_4[0]

# %%
auction15_5 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-mumbai-indians-mi-for-ipl-8-251227', header = 0)

# %%
auction15_5 = auction15_5[0]

# %%
auction15_6 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-rajasthan-royals-rr-for-ipl-8-251221', header = 0)

# %%
auction15_6 = auction15_6[0]

# %%
auction15_7 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-royal-challengers-bangalore-rcb-for-ipl-8-251195', header = 0)

# %%
auction15_7 = auction15_7[0]

# %%
auction15_8 = pd.read_html('https://www.cricketcountry.com/news/ipl-2015-auction-full-list-of-players-bought-by-sunrisers-hyderabad-srh-for-ipl-8-251213', header = 0)

# %%
auction15_8 = auction15_8[0]

# %%
auction15 = pd.concat([auction15_1, auction15_2, auction15_3, auction15_4, auction15_5, auction15_6, auction15_7, auction15_8])

# %%
auction15.sort_values(by = 'Players', inplace = True)

# %%
auction15.set_index(np.arange(0,67), inplace = True)

# %%
auction15
# Out:
#              Players       Base Price     Selling Price Playing Role  \
# 0        Aaron Finch  Rs. 1,00,00,000   Rs. 3,20,00,000      Batsman
# 1   Abhimanyu Mithun    Rs. 30,00,000     Rs. 30,00,000       Bowler
# 2         Adam Milne    Rs. 30,00,000     Rs. 70,00,000       Bowler
# 3     Aditya Garhwal    Rs. 10,00,000     Rs. 25,00,000  All-rounder
# 4     Aiden Blizzard    Rs. 30,00,000     Rs. 30,00,000      Batsman
# ..               ...              ...               ...          ...
# 62       Trent Boult    Rs. 50,00,000   Rs. 3,80,00,000       Bowler
# 63     Vaibhav Rawal    Rs. 10,00,000     Rs. 10,00,000      Batsman
# 64  Yogesh Golwalker    Rs. 10,00,000     Rs. 10,00,000      Batsman
# 65      Yuvraj Singh  Rs. 2,00,00,000  Rs. 16,00,00,000      Batsman
# 66       Zaheer Khan  Rs. 1,00,00,000   Rs. 4,00,00,000       Bowler
#
#         Country
# 0     Australia
# 1         India
# 2   New Zealand
# 3         India
# 4     Australia
# ..          ...
# ...

# %%
data = pd.read_excel('2015FinalOutput.xlsx')
for i in range(0, len(data['Player Name'])):
    for x in range(0, len(salary15)):
        if data['Player Name'][i] == salary15['Player'][x]:
            data['Salary'][i] = salary15['Actual Salary (INR)'][x]
            data['Country'][i] = salary15['Country'][x]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
for i in range(0, len(data['Player Name'])):
    for x in range(0, len(auction15)):
        if data['Player Name'][i] == auction15['Players'][x]:
            data['Salary'][i] = auction15['Selling Price'][x]
            data['Role'][i] = auction15['Playing Role'][x]
            data['Country'][i] = auction15['Country'][x]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data.to_excel('2015FinalOutput.xlsx')

# %%
import requests

url = 'https://www.crictracker.com/vivo-ipl-2016-auction-players-bought-sold-and-unsold/'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

salary16 = pd.read_html(r.text, header = 0)

# %%
salary16 = pd.concat([salary16[0], salary16[1], salary16[2], salary16[3], salary16[4], salary16[5], salary16[6], salary16[7]])

# %%
salary16.sort_values(by='Player', inplace = True)

# %%
salary16.set_index(np.arange(0,94), inplace = True)

# %%
salary16['Price Paid'] = salary16['Price Paid']/10000000

# %%
data = pd.read_excel('2016FinalOutput.xlsx')
for i in range(0, len(data['Player Name'])):
    for x in range(0, len(salary16)):
        if data['Player Name'][i] == salary16['Player'][x]:
            data['Salary'][i] = salary16['Price Paid'][x]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
data.to_excel('2016FinalOutput.xlsx')

# %%
data19 = pd.read_excel('2019FinalOutput.xlsx')

# %%
for i in range(len(data19['Salary(In Crore)'])):
    if data19['Salary(In Crore)'][i] != '-':
        data19['Salary(In Crore)'][i] = data19['Salary(In Crore)'][i]/100
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data19.to_excel('2019FinalOutput.xlsx')

# %%
data17 = pd.read_excel('2017FinalOutput.xlsx')

# %%
import urllib
import bs4 as bs
import re
import numpy as np
import pandas as pd

# %%
sheet = pd.read_excel('2015FinalOutput.xlsx')

# %%
number = len(sheet)

# %%
for i in range(0, 724):
    for x in range (0,number):
        url = 'https://moneyball.insidesport.co/single-player.php?id='+str(i)
        page = urllib.request.urlopen(url)
        from bs4 import BeautifulSoup
        soup = BeautifulSoup(page, "lxml")
        if soup.title.string.split()[:2] == sheet['Player Name'][x].split()[:2]:
            salarytable = pd.read_html(url)
            salarytable = salarytable[0]
            for z in range(0, len(salarytable)):
                if salarytable['Year'][z] == '2015' or salarytable['Year'][z] == '2015   (Retain)' or salarytable['Year'][z] == '2015   ( Injured )':
                    sheet['Salary'][x] = salarytable['Salary'][z]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# /opt/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# ...

# %%
url = 'https://moneyball.insidesport.co/single-player.php?id=242'
page = urllib.request.urlopen(url)
from bs4 import BeautifulSoup
soup = BeautifulSoup(page, "lxml")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <!-- Mirrored from html.iwthemes.com/sportscup/index.html by HTTrack Website Copier/3.x [XR&CO'2014], Wed, 14 Feb 2018 09:24:46 GMT -->
#  <head>
#   <!-- Basic -->
#   <meta charset="utf-8"/>
#   <title>
#    David Warner  IPL Sunrisers Hyderabad, IPL Salary ₹125,000,000 in 2020 and Total IPL income ₹ 585,017,300
#   </title>
#   <meta content="Total IPL income ₹585,017,300 , IPL Sunrisers Hyderabad , Australia and 2020 IPL salary ₹125,000,000 of David Warner . His Impact Rank 0 , Value for money Rank 0 and IPL rank 16 as well." name="description"/>
#   <link href="https://moneyball.insidesport.co/images/febicon.png" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
soup.title.string.split()[:2]
# Out:
# ['David', 'Warner']

# %%
test = pd.read_html(url)

# %%
test[0]['Year']
# Out:
# 0        2020 (Retain)
# 1        2019 (Retain)
# 2     2018 (Suspended)
# 3                 2017
# 4                 2016
# 5                 2015
# 6                 2014
# 7                 2013
# 8                 2012
# 9                 2011
# 10                2010
# 11                2009
# 12               Total
# Name: Year, dtype: object

# %%
sheet['Player Name'][0].split()[:2]

# %%
sheet.to_excel('2015Salary.xlsx')
